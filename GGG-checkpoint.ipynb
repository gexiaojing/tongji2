# %%
import requests
response=requests.get('https://ss0.bdstatic.com/94oJfD_bAAcT8t7mm9GUKT-xh_/timg?image&quality=100&size=b4000_4000&sec=1528526661&di=e073da6dcd170ae656c05cbaccba3c6f&src=http://pic.58pic.com/58pic/16/60/24/09m58PICqak_1024.jpg')
print(response.content)
with open('C:/Users/Ll/Desktop/test.jpg','wb')as f:
    f.write(response.content)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xfe\x00>CREATOR: gd-jpeg v1.0 (using IJG JPEG v62), default quality\n\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x01\xd4\x02\x8a\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x01\x00\x01\x05\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x04\x05\x06\x07\x03\x08\xff\xc4\x00P\x10\x00\x02\x01\x03\x02\x04\x02\x07\x03\x08\x06\x06\x08\x06\x03\x00\x00\x01\x02\x03\x04\x11\x05!\x06\x121AQq\x07\x13"a\x81\x91\xa1\x142\xb1\x15#BRbr\xc1\xd13Cs\xb2\xe1\xf0\x16\x17$4Sc%56Dt\x92\x93\xf1&T\x82\xa2\xd2\xe2V\x83\x84\xff\xc4\x00\x1b\x01\x01\x00\x02\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x05\x02\x04\x06\x03\x07\xff\xc4\x00+\x11\x0
# ...

# %%
import requests
response=requests.get('http://baidu.com')
with open('User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36','w',encoding='utf-8')as f:
    f.write(response.text)

# %%
import requests
login={'account':'2216023563','password':'jingyu0910'}
response=requests.post('http://httpbin.org/post',data=login)
print(response.text)
# Out:
# {"args":{},"data":"","files":{},"form":{"account":"2216023563","password":"jingyu0910"},"headers":{"Accept":"*/*","Accept-Encoding":"gzip, deflate","Connection":"close","Content-Length":"38","Content-Type":"application/x-www-form-urlencoded","Host":"httpbin.org","User-Agent":"python-requests/2.18.4"},"json":null,"origin":"223.104.178.203","url":"http://httpbin.org/post"}

# %%
import requests
response=requests.get('https://www.zhihu.com/explore')
print(response.text)
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %%
import requests
header={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36'}
response=requests.get('https://www.zhihu.com/explore',headers = header)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN" dropEffect="none" class="no-js no-auth ">
# <head>
# <meta charset="utf-8" />
#
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
# <meta name="renderer" content="webkit" />
# <meta http-equiv="X-ZA-Response-Id" content="1e3cb0c320efdb65e4d0b20406a2d6dc">
#
# ...

# %%
import requests
header={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36'}
response=requests.get('http://www.jianshu.com',headers=header,allow_redirects=True)
print(response.text)
# Out:
# <!DOCTYPE html>
# <!--[if IE 6]><html class="ie lt-ie8"><![endif]-->
# <!--[if IE 7]><html class="ie lt-ie8"><![endif]-->
# <!--[if IE 8]><html class="ie ie8"><![endif]-->
# <!--[if IE 9]><html class="ie ie9"><![endif]-->
# <!--[if !IE]><!--> <html> <!--<![endif]-->
#
# <head>
#   <meta charset="utf-8">
#   <meta http-equiv="X-UA-Compatible" content="IE=Edge">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0,user-scalable=no">
#
#   <!-- Start of Baidu Transcode -->
#   <meta http-equiv="Cache-Control" content="no-siteapp" />
#   <meta http-equiv="Cache-Control" content="no-transform" />
#   <meta name="applicable-device" content="pc,mobile">
#   <meta name="MobileOptimized" content="width"/>
#   <meta name="HandheldFriendly" content="true"/>
#   <meta name="mobile-agent" content="format=html5;url=https://www.jianshu.com/">
#   <!-- End of Baidu Transcode -->
#
# ...

# %%
import requests
requests.get('http://httpbin.org/cookies/set/number/123456')
response=requests.get('http://httpbin.org/cookies')
print(response.text)
# Out:
# {"cookies":{}}

# %%
import requests
s=requests.Session()#通过声明session告诉两次用的是一个浏览器
s.get('http://httpbin.org/cookies/set/number/123456')
response=s.get('http://httpbin.org/cookies')
print(response.text)
# Out:
# {"cookies":{"number":"123456"}}

# %%
import requests
from requests.packages import urllib3
urllib3.disable_warnings()
response=requests.get('https://www.12306.cn',verify=False)
print(response.status_code)
# Out:
# 200

# %%
import requests
response=requests.get('http://www.baidu.com',timeout=1)
print(response.status_code)
# Out:
# 200

# %%
import requests
try:
    response=requests.get('http://www.baidu.com',timeout=0.01)
    print(response.status_code)
except Exception as e:
    print(e)
# Out:
# HTTPConnectionPool(host='www.baidu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001D1085C6278>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))

# %%
url=['http://www.17k.com/book/2801193.html','http://www.17k.com/book/2767246.html']
file_path='C:/Users/Ll/Desktop/aaa.txt'
header={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36'}
import requests
response=requests.get('http://www.17k.com/')
with open(file_path,'a',encoding='utf-8') as f:
    for i in range(2):
        b = requests.get(url[i],headers = header)
        f.write(b.text)
    print(i)
# Out:
# 1
